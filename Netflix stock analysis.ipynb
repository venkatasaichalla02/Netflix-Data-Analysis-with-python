# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv('NFLX.csv')

# %% [markdown]
# ### Display the first few rows of the DataFrame

# %%
print("Table 1: The first few rows of the Data Frame")
print(df.head())
# Out:
# Table 1: The first few rows of the Data Frame
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %% [markdown]
# # Data Preprocessing

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')

# %% [markdown]
# ### Check for missing values and data types

# %%
print("\nTable 2: Data Entries and Types")
print(df.info())
# Out:
# Table 2: Data Entries and Types
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   datetime64[ns]
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 55.3 KB
# None

# %% [markdown]
# ## Drop rows with any missing values

# %%
df.dropna(inplace=True)

# %%
# Drop rows with any missing values
df.dropna(inplace=True)

# %% [markdown]
# ### DataFrame after removing null values

# %%
print("Data Frame after removing null values")
print(df)
# Out:
# Data Frame after removing null values
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1    2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2    2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3    2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4    2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...         ...         ...         ...         ...         ...         ...
# 1004 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# ...

# %% [markdown]
# # Ensure numeric columns are in the correct type

# %%
# Ensure numeric columns are in the correct type
numeric_columns = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric)

# %% [markdown]
# # Display the cleaned and transformed DataFrame

# %%
print("\nTable 3: Cleaned and Transformed Data Frame")
print(df.head())
# Out:
# Table 3: Cleaned and Transformed Data Frame
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
# Display the data types of the cleaned and transformed DataFrame
print("\nTable 4: Cleaned and Transformed Data Types")
print(df.dtypes)
# Out:
# Table 4: Cleaned and Transformed Data Types
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
# Display descriptive statistics for numerical columns
print("\nTable 5: Descriptive Statistics for Numerical Columns")
print(df.describe())
# Out:
# Table 5: Descriptive Statistics for Numerical Columns
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %% [markdown]
# ### Check value counts for a specific column

# %%
print("\nTable 6: Runtime Value Counts for 'Close' Column")
print(df['Close'].value_counts())
# Out:
# Table 6: Runtime Value Counts for 'Close' Column
# 357.320007    3
# 367.649994    2
# 325.220001    2
# 358.820007    2
# 518.909973    2
#              ..
# 380.399994    1
# 266.839996    1
# 367.679993    1
# 304.320007    1
# 266.000000    1
# Name: Close, Length: 988, dtype: int64

# %% [markdown]
# # Feature Selection

# %% [markdown]
# Calculate daily return

# %%
df['Daily Return'] = df['Adj Close'].pct_change()

# %% [markdown]
# Calculate moving averages

# %%
df['MA20'] = df['Adj Close'].rolling(window=20).mean()
df['MA50'] = df['Adj Close'].rolling(window=50).mean()

# %% [markdown]
# Display the first few rows with new features

# %%
print("\nTable 7: DataFrame with New Features")
print(df[['Date', 'Adj Close', 'Daily Return', 'MA20', 'MA50']].head())
# Out:
# Table 7: DataFrame with New Features
#         Date   Adj Close  Daily Return  MA20  MA50
# 0 2018-02-05  254.259995           NaN   NaN   NaN
# 1 2018-02-06  265.720001      0.045072   NaN   NaN
# 2 2018-02-07  264.559998     -0.004366   NaN   NaN
# 3 2018-02-08  250.100006     -0.054657   NaN   NaN
# 4 2018-02-09  249.470001     -0.002519   NaN   NaN

# %% [markdown]
# ## Data Analysis and Plotting

# %%
# Plot adjusted close price and moving averages
plt.figure(figsize=(14, 7))
plt.plot(df['Date'], df['Adj Close'], label='Adjusted Close Price')
plt.plot(df['Date'], df['MA20'], label='20-Day Moving Average')
plt.plot(df['Date'], df['MA50'], label='50-Day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('NFLX Stock Prices and Moving Averages')
plt.legend()
plt.show()

# %% [markdown]
# ## Plot trading volume

# %%
plt.figure(figsize=(14, 7))
plt.bar(df['Date'], df['Volume'], color='skyblue')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('NFLX Trading Volume Over Time')
plt.show()

# %% [markdown]
# ## Plot daily return

# %%
plt.figure(figsize=(14, 7))
plt.plot(df['Date'], df['Daily Return'], label='Daily Return', color='green')
plt.xlabel('Date')
plt.ylabel('Daily Return')
plt.title('NFLX Daily Returns Over Time')
plt.legend()
plt.show()

# %% [markdown]
# ## Plot distribution of daily returns

# %%
plt.figure(figsize=(14, 7))
plt.hist(df['Daily Return'].dropna(), bins=50, alpha=0.75, color='purple')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.title('Distribution of NFLX Daily Returns')
plt.show()

# %% [markdown]
# ## Results for Genre Analysis

# %%
df['YearMonth'] = df['Date'].dt.to_period('M')
monthly_return = df.groupby('YearMonth')['Daily Return'].mean()

# %%
# Plot monthly average daily return
plt.figure(figsize=(14, 7))
monthly_return.plot(kind='bar', color='orange')
plt.xlabel('Year-Month')
plt.ylabel('Average Daily Return')
plt.title('Monthly Average Daily Returns for NFLX')
plt.show()

# %% [markdown]
# # Correlation Analysis

# %% [markdown]
# Close and Volume

# %%
# Scatter plot between 'Close' and 'Volume'
plt.figure(figsize=(14, 7))
plt.scatter(df['Close'], df['Volume'], alpha=0.5, c='red')
plt.xlabel('Close Price')
plt.ylabel('Volume')
plt.title('Correlation between Close Price and Volume')
plt.show()

# %% [markdown]
# For Close and Daily Return

# %%
# Scatter plot between 'Close' and 'Daily Return'
plt.figure(figsize=(14, 7))
plt.scatter(df['Close'], df['Daily Return'], alpha=0.5, c='blue')
plt.xlabel('Close Price')
plt.ylabel('Daily Return')
plt.title('Correlation between Close Price and Daily Return')
plt.show()

# %% [markdown]
# ## Pair plot for selected features

# %%
sns.pairplot(df, vars=['Close', 'Volume', 'Daily Return'], diag_kind='kde')
plt.show()

# %% [markdown]
# ## Plotting Volume Analysis

# %%
volume_ranges = pd.cut(df['Volume'], bins=[0, 5000000, 10000000, 15000000, 20000000, df['Volume'].max()])
volume_counts = volume_ranges.value_counts()
plt.figure(figsize=(10, 6))
volume_counts.plot(kind='pie', autopct='%1.1f%%', colors=sns.color_palette('Set3'))
plt.title('Distribution of Trading Volume')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## Plotting Closing Price Analysis

# %%
close_ranges = pd.cut(df['Close'], bins=[0, 100, 200, 300, 400, df['Close'].max()])
close_counts = close_ranges.value_counts().sort_index()
plt.figure(figsize=(14, 7))
close_counts.plot(kind='bar', color='teal')
plt.xlabel('Closing Price Range')
plt.ylabel('Frequency')
plt.title('Distribution of Closing Prices')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Plotting Average Daily Return

# %%
df['Year'] = pd.to_datetime(df['Date']).dt.year

yearly_avg_daily_return = df.groupby('Year')['Daily Return'].mean()
plt.figure(figsize=(14, 7))
yearly_avg_daily_return.plot(kind='bar', color='salmon')
plt.xlabel('Year')
plt.ylabel('Average Daily Return')
plt.title('Yearly Average Daily Returns for NFLX')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Plotting Volume by Year

# %%
yearly_volume = df.groupby('Year')['Volume'].sum()
plt.figure(figsize=(14, 7))
yearly_volume.plot(kind='bar', color='skyblue')
plt.xlabel('Year')
plt.ylabel('Total Volume')
plt.title('Total Trading Volume by Year for NFLX')
plt.xticks(rotation=45)
plt.show()
